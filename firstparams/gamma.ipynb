# %%
import glob
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("whitegrid")

# %%
training = glob.glob('./gm*.csv')

# %%
training
# Out:
# ['./gm_1000_0.001_1.1.csv',
#  './gm_1000_0.001_1.0.csv',
#  './gm_1000_0.001_0.8.csv',
#  './gm_1000_0.001_0.7.csv',
#  './gm_1000_0.001_0.9.csv']

# %%
data = [pd.read_csv(x).rename(columns={'Unnamed: 0': 'iteration'}) for x in training]
data = pd.concat(data)

# %%
grouped = data.groupby('agent_hash')

# %%
plt.clf()
plt.title('Gamma Search wide')
plt.xlabel('Number of Games')
plt.ylabel('Mean Score')
legend_labels = []
for hash, g in grouped:
    plt.plot(g['mean_scores'])
    legend_labels.append((g['gamma'].values[0], 'max score:', g['scores'].max()))
plt.legend(legend_labels, loc='lower left')
plt.show()

# %%
training = glob.glob('./granular_gamma*.csv')
training
# Out:
# ['./granular_gamma_1000_0.001_0.98.csv',
#  './granular_gamma_1000_0.001_0.85.csv',
#  './granular_gamma_1000_0.001_1.0.csv',
#  './granular_gamma_1000_0.001_0.94.csv',
#  './granular_gamma_1000_0.001_0.82.csv',
#  './granular_gamma_1000_0.001_0.93.csv',
#  './granular_gamma_1000_0.001_0.95.csv',
#  './granular_gamma_1000_0.001_0.73.csv',
#  './granular_gamma_1000_0.001_0.88.csv',
#  './granular_gamma_1000_0.001_0.75.csv',
#  './granular_gamma_1000_0.001_0.8.csv',
#  './granular_gamma_1000_0.001_0.86.csv',
#  './granular_gamma_1000_0.001_0.7.csv',
#  './granular_gamma_1000_0.001_0.89.csv',
#  './granular_gamma_1000_0.001_0.72.csv',
#  './granular_gamma_1000_0.001_0.99.csv',
#  './granular_gamma_1000_0.001_0.92.csv',
#  './granular_gamma_1000_0.001_0.76.csv',
#  './granular_gamma_1000_0.001_0.9.csv',
#  './granular_gamma_1000_0.001_0.87.csv',
#  './granular_gamma_1000_0.001_0.81.csv',
#  './granular_gamma_1000_0.001_0.84.csv',
#  './granular_gamma_1000_0.001_0.77.csv',
#  './granular_gamma_1000_0.001_0.79.csv',
#  './granular_gamma_1000_0.001_0.83.csv',
#  './granular_gamma_1000_0.001_0.91.csv',
#  './granular_gamma_1000_0.001_0.71.csv',
#  './granular_gamma_1000_0.001_0.78.csv',
#  './granular_gamma_1000_0.001_0.74.csv',
#  './granular_gamma_1000_0.001_0.97.csv',
#  './granular_gamma_1000_0.001_0.96.csv']

# %%
data = [pd.read_csv(x).rename(columns={'Unnamed: 0': 'iteration'}) for x in training]
data = pd.concat(data)
grouped = data.groupby('agent_hash')
plt.figure(figsize=(10,9))
plt.clf()
plt.title('Gamma Search granular')
plt.xlabel('Number of Games')
plt.ylabel('Mean Score')
legend_labels = []
for hash, g in grouped:
    plt.plot(g['mean_scores'])
    legend_labels.append((g['gamma'].values[0], 'max score:', g['scores'].max(), 'max_mean:', round(g['mean_scores'].max(),2)))
plt.legend(legend_labels, loc='lower left')
plt.show()
